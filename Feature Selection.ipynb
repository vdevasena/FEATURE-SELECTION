# %% [markdown]
# Feature Selection

# %% [markdown]
# 1. Univariate Selection - use SelectKBest and function like chi2 from scikit.feature_selection

# %%
from sklearn.datasets import load_digits
from sklearn.feature_selection import SelectKBest, chi2

# %%
X, y = load_digits(return_X_y=True)

# %%
X.shape
# Out:
# (1797, 64)

# %%
X_new = SelectKBest(chi2, k=20).fit_transform(X, y)

# %%
X_new.shape
# Out:
# (1797, 20)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\devas\Downloads\archive\train.csv')

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
X = data.iloc[:,0:20] #independent columns
y = data.iloc[:,-1]

# %%
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
bestfeatures = SelectKBest(chi2, k=10)

# %%
bestfeatures
# Out:
# SelectKBest(k=10, score_func=<function chi2 at 0x000001924830B048>)

# %%
fit = bestfeatures.fit(X,y)

# %%
fit
# Out:
# SelectKBest(k=10, score_func=<function chi2 at 0x000001924830B048>)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
dfcolumns
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

# %%
featureScores
# Out:
#             Specs          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
featureScores.columns = ['Specs','Score']

# %%
print(featureScores.nlargest(10,'Score'))
# Out:
#             Specs          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# 2. Feature Selection - Score of the top 10 features( high score features are important features)

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_)
# Out:
# [0.0597055  0.01952483 0.03341787 0.01918473 0.03277037 0.01757309
#  0.03528364 0.03274649 0.03612464 0.03337236 0.03374179 0.04768222
#  0.04926675 0.39527709 0.03383941 0.03350214 0.03457183 0.01418276
#  0.01856681 0.01966569]

# %%
feat_importances = pd.Series(model.feature_importances_,index=X.columns)

# %%
feat_importances
# Out:
# battery_power    0.059705
# blue             0.019525
# clock_speed      0.033418
# dual_sim         0.019185
# fc               0.032770
# four_g           0.017573
# int_memory       0.035284
# m_dep            0.032746
# mobile_wt        0.036125
# n_cores          0.033372
# pc               0.033742
# px_height        0.047682
# px_width         0.049267
# ram              0.395277
# sc_h             0.033839
# sc_w             0.033502
# talk_time        0.034572
# three_g          0.014183
# touch_screen     0.018567
# wifi             0.019666
# dtype: float64

# %%
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# 3.Correlation Matrix with heatmap

# %%
import seaborn as sns

# %%
corrmat = data.corr()

# %%
corrmat
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
top_corr_features = corrmat.index

# %%
top_corr_features
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))

# %%
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
g=sns.heatmap(corrmat,annot=True,cmap="RdYlGn")
